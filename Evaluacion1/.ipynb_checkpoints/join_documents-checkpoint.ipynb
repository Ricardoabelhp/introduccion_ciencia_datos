# %% [markdown]
# # Instalar los componentes para leer desde Excel.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # Leer archivos de Excel - Class

# %%
df_class = pd.read_excel('C:\\ricardo_hernandez\\CLASS.xlsx')

# %% [markdown]
# Cambiar de nombre a las columnas

# %%
df_class.rename( columns = { "Economy": "economy",  "Code": "iso3", "Region":"region", "Income group": "income_group", "Lending category": "lending_category"}, inplace=True)

# %%
display(df_class)
# Out:
#                                         economy iso3  \
# 0                                         Aruba  ABW
# 1                                   Afghanistan  AFG
# 2                                        Angola  AGO
# 3                                       Albania  ALB
# 4                                       Andorra  AND
# ..                                          ...  ...
# 262                          Sub-Saharan Africa  SSF
# 263  Sub-Saharan Africa (excluding high income)  SSA
# 264             Sub-Saharan Africa (IDA & IBRD)  TSS
# 265                         Upper middle income  UMC
# 266                                       World  WLD
#
#                         region         income_group lending_category
# 0    Latin America & Caribbean          High income              NaN
# 1                   South Asia           Low income              IDA
# 2           Sub-Saharan Africa  Lower middle income             IBRD
# ...

# %% [markdown]
# # Leer archivos de Excel - Codigo Telefono

# %%
df_codigo_telefono = pd.read_excel('C:\\ricardo_hernandez\\codigo_telefono.xlsx')

# %%
df_codigo_telefono['nombre'] = df_codigo_telefono['nombre'].str.replace('"','')
df_codigo_telefono['name'] = df_codigo_telefono['name'].str.replace('"','')
df_codigo_telefono['nom'] = df_codigo_telefono['nom'].str.replace('"','')
df_codigo_telefono['iso2'] = df_codigo_telefono['iso2'].str.replace('"','')
df_codigo_telefono['iso3'] = df_codigo_telefono['iso3'].str.replace('"','')
df_codigo_telefono['phone_code'] = df_codigo_telefono['phone_code'].str.replace('"','')

# %%
df_codigo_telefono.rename( columns = { "nombre": "nom_esp",  "name": "nom_ingles", "nom":"nom_otro", "iso2": "iso2", "iso3": "iso3", "phone_code":"phone_code"}, inplace=True)

# %%
display(df_codigo_telefono)
# Out:
#              nom_esp         nom_ingles          nom_otro iso2 iso3 phone_code
# 0         Afganistán        Afghanistan       Afghanistan   AF  AFG         93
# 1            Albania            Albania           Albanie   AL  ALB        355
# 2           Alemania            Germany         Allemagne   DE  DEU         49
# 3            Algeria            Algeria           Algérie   DZ  DZA        213
# 4            Andorra            Andorra           Andorra   AD  AND        376
# ..               ...                ...               ...  ...  ...        ...
# 241  Wallis y Futuna  Wallis and Futuna  Wallis et Futuna   WF  WLF        681
# 242            Yemen              Yemen             Yémen   YE  YEM        967
# 243           Yibuti           Djibouti          Djibouti   DJ  DJI        253
# 244           Zambia             Zambia            Zambie   ZM  ZMB        260
# 245         Zimbabue           Zimbabwe          Zimbabwe   ZW  ZWE        263
#
# [246 rows x 6 columns]

# %% [markdown]
# # Leer archivos de Excel - country_isos

# %%
df_country_isos = pd.read_excel('C:\\ricardo_hernandez\\country_isos.xlsx')

# %%
df_country_isos.rename( columns = { "Country": "country",  "Officialstatename": "official_state_name", "InternetccTLD":"internet_cc_TLD", "iso2": "iso2", "iso3": "iso3"}, inplace=True)

# %%
display(df_country_isos)
# Out:
#                  country                          official_state_name  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     internet_cc_TLD iso2 iso3
# 0               .af   AF  AFG
# 1               .al   AL  ALB
# 2               .dz   DZ  DZA
# ...

# %% [markdown]
# # Leer archivos de Excel - poblacion

# %%
df_poblacion = pd.read_excel('C:\\ricardo_hernandez\\poblacion.xls')

# %%
display(df_poblacion)
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
df_poblacion = df_poblacion[["Country Name","Country Code","Indicator Name","2022"]]

# %%
df_poblacion.rename( columns = { "Country Name": "country_name",  "Country Code": "iso3", "Indicator Name":"indicator_name", "2022": "2022"}, inplace=True)
display(df_poblacion)
# Out:
#         country_name iso3    indicator_name         2022
# 0              Aruba  ABW  Población, total     106445.0
# 1                NaN  AFE  Población, total  720839314.0
# 2         Afganistán  AFG  Población, total   41128771.0
# 3                NaN  AFW  Población, total  490330870.0
# 4             Angola  AGO  Población, total   35588987.0
# ..               ...  ...               ...          ...
# 261           Kosovo  XKX  Población, total    1761985.0
# 262  Yemen, Rep. del  YEM  Población, total   33696614.0
# 263        Sudáfrica  ZAF  Población, total   59893885.0
# 264           Zambia  ZMB  Población, total   20017675.0
# 265         Zimbabwe  ZWE  Población, total   16320537.0
#
# [266 rows x 4 columns]

# %% [markdown]
# # Unir tablas en base en country iso con el dataframe class

# %%
result = pd.merge(df_country_isos, df_class, on=["iso3"])

# %%
display(result)
# Out:
#                  country                          official_state_name  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 165           UZBEKISTAN                   The Republic of Uzbekistan
# 166             VIET NAM           The Socialist Republic of Viet Nam
# 167                YEMEN                        The Republic of Yemen
# 168               ZAMBIA                       The Republic of Zambia
# 169             ZIMBABWE                     The Republic of Zimbabwe
#
#     internet_cc_TLD iso2 iso3              economy  \
# 0               .af   AF  AFG          Afghanistan
# ...

# %%
result_country_iso_class = result[["country","iso3","iso2","region", "income_group", "lending_category", "official_state_name", "internet_cc_TLD"]]
display(result_country_iso_class)
# Out:
#                  country iso3 iso2                      region  \
# 0            AFGHANISTAN  AFG   AF                  South Asia
# 1                ALBANIA  ALB   AL       Europe & Central Asia
# 2                ALGERIA  DZA   DZ  Middle East & North Africa
# 3                 ANGOLA  AGO   AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG   AG   Latin America & Caribbean
# ..                   ...  ...  ...                         ...
# 165           UZBEKISTAN  UZB   UZ       Europe & Central Asia
# 166             VIET NAM  VNM   VN         East Asia & Pacific
# 167                YEMEN  YEM   YE  Middle East & North Africa
# 168               ZAMBIA  ZMB   ZM          Sub-Saharan Africa
# 169             ZIMBABWE  ZWE   ZW          Sub-Saharan Africa
#
#             income_group lending_category  \
# 0             Low income              IDA
# 1    Upper middle income             IBRD
# 2    Lower middle income             IBRD
# ...

# %% [markdown]
# # Unir tablas del resultado anterior con df_codigo_telefono

# %%
result_2 = pd.merge(result_country_iso_class, df_codigo_telefono, on=["iso3"])

# %%
display(result_2)
# Out:
#                  country iso3 iso2_x                      region  \
# 0            AFGHANISTAN  AFG     AF                  South Asia
# 1                ALBANIA  ALB     AL       Europe & Central Asia
# 2                ALGERIA  DZA     DZ  Middle East & North Africa
# 3                 ANGOLA  AGO     AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG     AG   Latin America & Caribbean
# ..                   ...  ...    ...                         ...
# 164           UZBEKISTAN  UZB     UZ       Europe & Central Asia
# 165             VIET NAM  VNM     VN         East Asia & Pacific
# 166                YEMEN  YEM     YE  Middle East & North Africa
# 167               ZAMBIA  ZMB     ZM          Sub-Saharan Africa
# 168             ZIMBABWE  ZWE     ZW          Sub-Saharan Africa
#
#             income_group lending_category  \
# 0             Low income              IDA
# 1    Upper middle income             IBRD
# 2    Lower middle income             IBRD
# ...

# %%
result_cod_tel = result_2[["country","iso3","iso2_x","region", "income_group", "lending_category", "official_state_name", "internet_cc_TLD", "phone_code"]]
display(result_cod_tel)
# Out:
#                  country iso3 iso2_x                      region  \
# 0            AFGHANISTAN  AFG     AF                  South Asia
# 1                ALBANIA  ALB     AL       Europe & Central Asia
# 2                ALGERIA  DZA     DZ  Middle East & North Africa
# 3                 ANGOLA  AGO     AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG     AG   Latin America & Caribbean
# ..                   ...  ...    ...                         ...
# 164           UZBEKISTAN  UZB     UZ       Europe & Central Asia
# 165             VIET NAM  VNM     VN         East Asia & Pacific
# 166                YEMEN  YEM     YE  Middle East & North Africa
# 167               ZAMBIA  ZMB     ZM          Sub-Saharan Africa
# 168             ZIMBABWE  ZWE     ZW          Sub-Saharan Africa
#
#             income_group lending_category  \
# 0             Low income              IDA
# 1    Upper middle income             IBRD
# 2    Lower middle income             IBRD
# ...

# %% [markdown]
# # Unir el dataframe anterior con el dataframe poblacion

# %%
result_3 = pd.merge(result_cod_tel, df_poblacion, on=["iso3"])

# %%
display(result_3)
# Out:
#                  country iso3 iso2_x                      region  \
# 0            AFGHANISTAN  AFG     AF                  South Asia
# 1                ALBANIA  ALB     AL       Europe & Central Asia
# 2                ALGERIA  DZA     DZ  Middle East & North Africa
# 3                 ANGOLA  AGO     AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG     AG   Latin America & Caribbean
# ..                   ...  ...    ...                         ...
# 164           UZBEKISTAN  UZB     UZ       Europe & Central Asia
# 165             VIET NAM  VNM     VN         East Asia & Pacific
# 166                YEMEN  YEM     YE  Middle East & North Africa
# 167               ZAMBIA  ZMB     ZM          Sub-Saharan Africa
# 168             ZIMBABWE  ZWE     ZW          Sub-Saharan Africa
#
#             income_group lending_category  \
# 0             Low income              IDA
# 1    Upper middle income             IBRD
# 2    Lower middle income             IBRD
# ...

# %%
result_final = result_3[["country","iso3","iso2_x","region", "income_group", "lending_category", "official_state_name", "internet_cc_TLD", "phone_code", "indicator_name","2022"]]
display(result_final)
# Out:
#                  country iso3 iso2_x                      region  \
# 0            AFGHANISTAN  AFG     AF                  South Asia
# 1                ALBANIA  ALB     AL       Europe & Central Asia
# 2                ALGERIA  DZA     DZ  Middle East & North Africa
# 3                 ANGOLA  AGO     AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG     AG   Latin America & Caribbean
# ..                   ...  ...    ...                         ...
# 164           UZBEKISTAN  UZB     UZ       Europe & Central Asia
# 165             VIET NAM  VNM     VN         East Asia & Pacific
# 166                YEMEN  YEM     YE  Middle East & North Africa
# 167               ZAMBIA  ZMB     ZM          Sub-Saharan Africa
# 168             ZIMBABWE  ZWE     ZW          Sub-Saharan Africa
#
#             income_group lending_category  \
# 0             Low income              IDA
# 1    Upper middle income             IBRD
# 2    Lower middle income             IBRD
# ...

# %%
result_final = result_final[["country","iso3","iso2_x","region", "income_group", "official_state_name", "internet_cc_TLD", "phone_code","2022"]]
display(result_final)
# Out:
#                  country iso3 iso2_x                      region  \
# 0            AFGHANISTAN  AFG     AF                  South Asia
# 1                ALBANIA  ALB     AL       Europe & Central Asia
# 2                ALGERIA  DZA     DZ  Middle East & North Africa
# 3                 ANGOLA  AGO     AO          Sub-Saharan Africa
# 4    ANTIGUA AND BARBUDA  ATG     AG   Latin America & Caribbean
# ..                   ...  ...    ...                         ...
# 164           UZBEKISTAN  UZB     UZ       Europe & Central Asia
# 165             VIET NAM  VNM     VN         East Asia & Pacific
# 166                YEMEN  YEM     YE  Middle East & North Africa
# 167               ZAMBIA  ZMB     ZM          Sub-Saharan Africa
# 168             ZIMBABWE  ZWE     ZW          Sub-Saharan Africa
#
#             income_group                          official_state_name  \
# 0             Low income          The Islamic Republic of Afghanistan
# ...
