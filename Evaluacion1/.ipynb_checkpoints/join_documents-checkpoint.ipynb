# %% [markdown]
# # Instalar los componentes para leer desde Excel.

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\juanp\miniconda3\envs\myenv\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\juanp\miniconda3\envs\myenv\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\juanp\miniconda3\envs\myenv\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # Leer archivos de Excel - Class

# %%
df_class = pd.read_excel('C:\\ricardo_hernandez\\CLASS.xlsx')

# %%
display(df_class)
# Out:
#                                         Economy Code  \
# 0                                         Aruba  ABW
# 1                                   Afghanistan  AFG
# 2                                        Angola  AGO
# 3                                       Albania  ALB
# 4                                       Andorra  AND
# ..                                          ...  ...
# 262                          Sub-Saharan Africa  SSF
# 263  Sub-Saharan Africa (excluding high income)  SSA
# 264             Sub-Saharan Africa (IDA & IBRD)  TSS
# 265                         Upper middle income  UMC
# 266                                       World  WLD
#
#                         Region         Income group Lending category
# 0    Latin America & Caribbean          High income              NaN
# 1                   South Asia           Low income              IDA
# 2           Sub-Saharan Africa  Lower middle income             IBRD
# 3        Europe & Central Asia  Upper middle income             IBRD
# 4        Europe & Central Asia          High income              NaN
# ..                         ...                  ...              ...
# 262                        NaN                  NaN              NaN
# 263                        NaN                  NaN              NaN
# 264                        NaN                  NaN              NaN
# 265                        NaN                  NaN              NaN
# 266                        NaN                  NaN              NaN
#
# [267 rows x 5 columns]

# %% [markdown]
# # Leer archivos de Excel - Codigo Telefono

# %%
df_codigo_telefono = pd.read_excel('C:\\ricardo_hernandez\\codigo_telefono.xlsx')

# %%
display(df_codigo_telefono)
# Out:
#                 nombre                 name                 nom  iso2   iso3  \
# 0         "Afganistán"        "Afghanistan"       "Afghanistan"  "AF"  "AFG"
# 1            "Albania"            "Albania"           "Albanie"  "AL"  "ALB"
# 2           "Alemania"            "Germany"         "Allemagne"  "DE"  "DEU"
# 3            "Algeria"            "Algeria"           "Algérie"  "DZ"  "DZA"
# 4            "Andorra"            "Andorra"           "Andorra"  "AD"  "AND"
# ..                 ...                  ...                 ...   ...    ...
# 241  "Wallis y Futuna"  "Wallis and Futuna"  "Wallis et Futuna"  "WF"  "WLF"
# 242            "Yemen"              "Yemen"             "Yémen"  "YE"  "YEM"
# 243           "Yibuti"           "Djibouti"          "Djibouti"  "DJ"  "DJI"
# 244           "Zambia"             "Zambia"            "Zambie"  "ZM"  "ZMB"
# 245         "Zimbabue"           "Zimbabwe"          "Zimbabwe"  "ZW"  "ZWE"
#
#     phone_code
# 0         "93"
# 1        "355"
# 2         "49"
# 3        "213"
# 4        "376"
# ..         ...
# 241      "681"
# 242      "967"
# 243      "253"
# 244      "260"
# 245      "263"
#
# [246 rows x 6 columns]

# %% [markdown]
# # Leer archivos de Excel - country_isos

# %%
df_country_isos = pd.read_excel('C:\\ricardo_hernandez\\country_isos.xlsx')

# %%
display(df_country_isos)
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %% [markdown]
# # Leer archivos de Excel - poblacion

# %%
df_poblacion = pd.read_excel('C:\\ricardo_hernandez\\poblacion.xls')

# %%
display(df_poblacion)
# Out:
#            Data Source Indicadores del desarrollo mundial        Unnamed: 2  \
# 0    Last Updated Date                2023-09-19 00:00:00               NaN
# 1                  NaN                                NaN               NaN
# 2         Country Name                       Country Code    Indicator Name
# 3                Aruba                                ABW  Población, total
# 4                  NaN                                AFE  Población, total
# ..                 ...                                ...               ...
# 264             Kosovo                                XKX  Población, total
# 265    Yemen, Rep. del                                YEM  Población, total
# 266          Sudáfrica                                ZAF  Población, total
# 267             Zambia                                ZMB  Población, total
# 268           Zimbabwe                                ZWE  Población, total
#
#          Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2    Indicator Code       1960.0       1961.0       1962.0       1963.0
# 3       SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# 4       SP.POP.TOTL  130692579.0  134169237.0  137835590.0  141630546.0
# ..              ...          ...          ...          ...          ...
# 264     SP.POP.TOTL     947000.0     966000.0     994000.0    1022000.0
# 265     SP.POP.TOTL    5542459.0    5646668.0    5753386.0    5860197.0
# 266     SP.POP.TOTL   16520441.0   16989464.0   17503133.0   18042215.0
# 267     SP.POP.TOTL    3119430.0    3219451.0    3323427.0    3431381.0
# 268     SP.POP.TOTL    3806310.0    3925952.0    4049778.0    4177931.0
#
#       Unnamed: 8   Unnamed: 9  ...  Unnamed: 57  Unnamed: 58  Unnamed: 59  \
# 0            NaN          NaN  ...          NaN          NaN          NaN
# 1            NaN          NaN  ...          NaN          NaN          NaN
# 2         1964.0       1965.0  ...       2013.0       2014.0       2015.0
# 3        58178.0      58782.0  ...     102880.0     103594.0     104257.0
# 4    145605995.0  149742351.0  ...  567892149.0  583651101.0  600008424.0
# ..           ...          ...  ...          ...          ...          ...
# 264    1050000.0    1078000.0  ...    1818117.0    1812771.0    1788196.0
# 265    5973803.0    6097298.0  ...   26984002.0   27753304.0   28516545.0
# 266   18603097.0   19187194.0  ...   53873616.0   54729551.0   55876504.0
# 267    3542764.0    3658024.0  ...   15234976.0   15737793.0   16248230.0
# 268    4310332.0    4447149.0  ...   13555422.0   13855753.0   14154937.0
#
#      Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2         2016.0       2017.0       2018.0       2019.0       2020.0
# 3       104874.0     105439.0     105962.0     106442.0     106585.0
# 4    616377605.0  632746570.0  649757148.0  667242986.0  685112979.0
# ..           ...          ...          ...          ...          ...
# 264    1777557.0    1791003.0    1797085.0    1788878.0    1790133.0
# 265   29274002.0   30034389.0   30790513.0   31546691.0   32284046.0
# 266   56422274.0   56641209.0   57339635.0   58087055.0   58801927.0
# 267   16767761.0   17298054.0   17835893.0   18380477.0   18927715.0
# 268   14452704.0   14751101.0   15052184.0   15354608.0   15669666.0
#
#      Unnamed: 65  Unnamed: 66
# 0            NaN          NaN
# 1            NaN          NaN
# 2         2021.0       2022.0
# 3       106537.0     106445.0
# 4    702977106.0  720839314.0
# ..           ...          ...
# 264    1786038.0    1761985.0
# 265   32981641.0   33696614.0
# 266   59392255.0   59893885.0
# 267   19473125.0   20017675.0
# 268   15993524.0   16320537.0
#
# [269 rows x 67 columns]
